# %% [markdown]
# # EDA with Python Libraries
# ## Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('wine.csv')
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
df = pd.DataFrame(data)
# Line plot of Values1 and Values2
sns.pairplot(x_vars='Magnesium', y_vars='Alcohol', data=df,hue='Hue')
# sns.lineplot(x='Category', y='Values2', data=df, label='Values2',marker='o',color='red')

# Customize and show plot
# plt.title('Line Plot')
# plt.xlabel('Category')
# plt.ylabel('Values')
# plt.legend()
plt.show()

# %%
df = pd.DataFrame(data)
# Line plot of Values1 and Values2
# sns.pairplot(x_vars='Magnesium', y_vars='Alcohol', data=df,hue='Hue')
sns.lmplot(x='Alcohol', y='Malic_Acid', data=df)
# sns.lineplot(x='Category', y='Values2', data=df, label='Values2',marker='o',color='red')

# Customize and show plot
# plt.title('Line Plot')
# plt.xlabel('Category')
# plt.ylabel('Values')
# plt.legend()
plt.show()

# %%
sns.boxplot(
    x='Ash', 
    y='Alcohol', 
    data=df
)
plt.show()

# %%
sns.scatterplot(x='Magnesium', y='Alcohol', data=df)
# sns.scatterplot(x_vars='Alchohol',y_vars='Magnesium',data=df)
plt.show()
sns.lineplot(x='Alcohol',y='Ash',data=df)
plt.show()

# %%
sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
