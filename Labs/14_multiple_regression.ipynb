# %% [markdown]
# # Machine Learning (16-7-2024)

# %% [markdown]
# ## Supervised Learning (Multiple Linear Regression)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error

# Sample dataset (replace with your generated data)
data = {'experience_years': [2, 5, 3, 7, 4, 6, 8, 1, 9, 10],
        'last_salary': [50, 70, 60, 85, 65, 75, 90, 45, 100, 110],
        'gpa': [3.2, 3.5, 3.8, 3.9, 3.4, 3.7, 4.0, 3.1, 3.6, 3.3],
        'expect_salary': [75, 95, 80, 110, 85, 90, 120, 65, 130, 140]}

df = pd.DataFrame(data)

# Separate features and target variable
X = df[['experience_years', 'last_salary', 'gpa']]
y = df['expect_salary']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# Evaluate the model by MSE
test_mse = mean_squared_error(y_test, y_pred)
print(f"Testing Mean Squared Error (MSE): {test_mse}")

# Plot the predicted vs. actual values
plt.scatter(y_test, y_pred,color='green', label='Test Data')
#plt.scatter(X_train, y_train,color='blue', label='Train Data')

plt.xlabel("Actual Expected Salary")
plt.ylabel("Predicted Expected Salary")
plt.title("Actual vs. Predicted Expected Salary")
plt.show()
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.hlines(y=0, xmin=min(y_pred), xmax=max(y_pred), color='red')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
# Out:
# Testing Mean Squared Error (MSE): 61.148961680984804

# %%
data=pd.read_csv('Real_estate.csv')
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df = pd.DataFrame(data)

# Separate features and target variable
X = df[['X2 house age', 'X3 distance to the nearest MRT station']]
y = df['Y house price of unit area']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# Evaluate the model by MSE
test_mse = mean_squared_error(y_test, y_pred)
print(f"Testing Mean Squared Error (MSE): {test_mse}")

# Plot the predicted vs. actual values
plt.scatter(y_test, y_pred,color='green', label='Test Data')
#plt.scatter(X_train, y_train,color='blue', label='Train Data')

plt.xlabel("House Age and MRT Distance")
plt.ylabel("Predicted House Price")
plt.title("Effect of House Price on Age and Mrt Distance")
plt.show()
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.hlines(y=0, xmin=min(y_pred), xmax=max(y_pred), color='red')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
# Out:
# Testing Mean Squared Error (MSE): 86.12035025845773

# %%
data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



# Define input (X) and output (Y)
X = df[['X2 house age', 'X3 distance to the nearest MRT station']]
Y = df['Y house price of unit area']

# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Train a Linear Regression model
model = LinearRegression()
model.fit(X_train, Y_train)

# Predict on the test data
Y_pred = model.predict(X_test)

# Calculate the Mean Squared Error
mse = mean_squared_error(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")

# 3D Plot with Matplotlib
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot true data points (blue)
ax.scatter(X_test['X2 house age'], X_test['X3 distance to the nearest MRT station'], Y_test, color='blue', label='True Values')

# Plot predicted data points (red)
ax.scatter(X_test['X2 house age'], X_test['X3 distance to the nearest MRT station'], Y_pred, color='red', label='Predicted Values')

# Create a grid for the regression plane
X1_range = np.linspace(X['X2 house age'].min(), X['X2 house age'].max(), 100)
X2_range = np.linspace(X['X3 distance to the nearest MRT station'].min(), X['X3 distance to the nearest MRT station'].max(), 100)
X1_grid, X2_grid = np.meshgrid(X1_range, X2_range)

# Calculate Z values for the regression plane
Z_grid = model.intercept_ + model.coef_[0] * X1_grid + model.coef_[1] * X2_grid

# Plot the regression plane
ax.plot_surface(X1_grid, X2_grid, Z_grid, alpha=0.5, cmap='plasma', rstride=100, cstride=100)

# Labels and title
ax.set_xlabel('House Age')
ax.set_ylabel('MRT Distance')
ax.set_zlabel('Y')
ax.set_title('Multivariate Linear Regression 3D Plot')

plt.legend()
plt.show()
# Out:
# Mean Squared Error: 71.20551591407651

# %%
data=pd.read_csv('heart_disease_dataset.csv')
data.head()
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1            NaN               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3            NaN               4             No      Yes      No
# 4            NaN               6             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# ...

# %%
df = pd.DataFrame(data)

# Separate features and target variable
X = df[['Cholesterol', 'Age']]
y = df['Heart Disease']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# Evaluate the model by MSE
test_mse = mean_squared_error(y_test, y_pred)
print(f"Testing Mean Squared Error (MSE): {test_mse}")

# Plot the predicted vs. actual values
plt.scatter(y_test, y_pred,color='green', label='Test Data')
#plt.scatter(X_train, y_train,color='blue', label='Train Data')

plt.xlabel("Cholestrol and Age")
plt.ylabel("Disease")
plt.title("Effect of Cholesterol and Age on Heart Disease")
plt.show()
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.hlines(y=0, xmin=min(y_pred), xmax=max(y_pred), color='red')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
# Out:
# Testing Mean Squared Error (MSE): 0.10889154635817815
