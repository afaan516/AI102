# %% [markdown]
# # Project 1: Heart Disease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. What are the basic characteristics of the dataset?

# %%
df= pd.read_csv('heart_disease_dataset.csv')
df.info()
# df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
df.head()
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1            NaN               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3            NaN               4             No      Yes      No
# 4            NaN               6             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# ...

# %%
df.tail()
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 995          Heavy               5             No      Yes     Yes
# 996            NaN               6             No       No      No
# 997       Moderate               4            Yes       No     Yes
# 998            NaN               8            Yes      Yes      No
# 999            NaN               6             No       No     Yes
#
#      Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 995            10          120                      No  Non-anginal Pain
# ...

# %% [markdown]
# # 2. What is the distribution of gender in the dataset?

# %%
df.value_counts('Gender')
# print(df['Gender'].value_counts())
# Out:
# Gender
# Female    503
# Male      497
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Gender',color='skyblue')
plt.title('Gender in Dataset')
plt.xlabel('Gender')
plt.ylabel('count')
# plt.legend(['Male','Female'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %% [markdown]
# # 3. How prevalent is heart disease in the dataset?

# %%
# Analyzing heart disease count
df.value_counts('Heart Disease')
# Out:
# Heart Disease
# 0    608
# 1    392
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Heart Disease',hue='Heart Disease')
plt.title('Heart Disease Dataset')
plt.xlabel('YES or NO')
plt.ylabel('Peoples')
plt.legend(['No','Yes'])
plt.show()

# %% [markdown]
# # 4. Are there any missing values in the dataset?

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Cholesterol                  0
# Blood Pressure               0
# Heart Rate                   0
# Smoking                      0
# Alcohol Intake             340
# Exercise Hours               0
# Family History               0
# Diabetes                     0
# Obesity                      0
# Stress Level                 0
# Blood Sugar                  0
# Exercise Induced Angina      0
# Chest Pain Type              0
# Heart Disease                0
# dtype: int64

# %%
df['Alcohol Intake']=df['Alcohol Intake'].fillna('No')
# df['Smoking Status']=df['Smoking Status'].fillna('No')

df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Cholesterol                0
# Blood Pressure             0
# Heart Rate                 0
# Smoking                    0
# Alcohol Intake             0
# Exercise Hours             0
# Family History             0
# Diabetes                   0
# Obesity                    0
# Stress Level               0
# Blood Sugar                0
# Exercise Induced Angina    0
# Chest Pain Type            0
# Heart Disease              0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  Cholesterol  Blood Pressure   Heart Rate  Exercise Hours  \
# count  1000.000000  1000.000000       1000.0000  1000.000000     1000.000000
# mean     52.293000   249.939000        135.2810    79.204000        4.529000
# std      15.727126    57.914673         26.3883    11.486092        2.934241
# min      25.000000   150.000000         90.0000    60.000000        0.000000
# 25%      39.000000   200.000000        112.7500    70.000000        2.000000
# 50%      52.000000   248.000000        136.0000    79.000000        4.500000
# 75%      66.000000   299.000000        159.0000    89.000000        7.000000
# max      79.000000   349.000000        179.0000    99.000000        9.000000
#
#        Stress Level  Blood Sugar  Heart Disease
# count   1000.000000  1000.000000    1000.000000
# mean       5.646000   134.941000       0.392000
# std        2.831024    36.699624       0.488441
# min        1.000000    70.000000       0.000000
# ...

# %% [markdown]
# # 6. Are there any outliers in the numerical columns?

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Gender',
#  'Cholesterol',
#  'Blood Pressure',
#  'Heart Rate',
#  'Smoking',
#  'Alcohol Intake',
#  'Exercise Hours',
#  'Family History',
#  'Diabetes',
#  'Obesity',
#  'Stress Level',
#  'Blood Sugar',
#  'Exercise Induced Angina',
#  'Chest Pain Type',
#  'Heart Disease']

# %%
sns.boxplot(data=df,y='Cholesterol')

plt.ylabel('Cholesterol')

plt.show()

# %%
sns.boxplot(data=df,y='Heart Rate')

plt.ylabel('Heart Rate')
plt.title('Heart Rate Distribution')
# Out:
# Text(0.5, 1.0, 'Heart Rate Distribution')

# %%
sns.boxplot(data=df,y='Blood Pressure')
plt.ylabel( 'Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
sns.boxplot(data=df,y='Blood Sugar')
plt.ylabel('Blood Sugar')
# Out:
# Text(0, 0.5, 'Blood Sugar')

# %% [markdown]
# # 7. What is the relationship between cholesterol levels and heart disease?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
sns.violinplot(data=df, x="Heart Disease", y="Cholesterol")
plt.xlabel('Heart Disease')
plt.ylabel('Cholestrol')
plt.title('Violin Plot')
plt.show()

# %% [markdown]
# # 9. What is the distribution of lifestyle-related features like Smoking, Alcohol Intake, and Exercise Hours?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
sns.countplot(x='Smoking', data=df,width=0.4)
plt.xlabel('Smoking')
plt.ylabel('Total no of Counts')
plt.title('Graph')
plt.show()

# %%
sns.countplot(x='Alcohol Intake', data=df)
plt.xlabel('Alcohol Intake')
plt.ylabel('Total no of Counts')
plt.title('Grpah')
plt.show()

# %%
sns.histplot(x='Exercise Hours',kde=True,data=df,bins=10)
plt.xlabel('Exercise Hours')
plt.ylabel('Total no of Counts')
plt.title('Grapph with KDE')
plt.show()

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1,3,1)
sns.countplot(x='Smoking', data=df)
plt.xlabel('Smoking')
plt.ylabel('Total no of counts')
plt.title('Graph 1')
plt.subplot(1,3,2)
sns.countplot(x='Alcohol Intake', data=df)
plt.xlabel('Alcohol Intake')
plt.ylabel('Total no of counts')
plt.title('Graph 2')
plt.subplot(1,3,3)
sns.histplot(x='Exercise Hours',kde=True,data=df,bins=10)
plt.xlabel('Exercise Hours')
plt.ylabel('Total no of counts')
plt.title('Graph 3')

plt.show()

# presenting all above insights togther for a clear view

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Family History', y='Heart Disease', data=df,width=0.5)
# sns.barplot(x='Family History', y='Heart Disease', data=df, estimator=df['Family History'].mean(x))

plt.xlabel('Family History of Heart Disease')
plt.ylabel(' Heart Disease')
plt.title('Heart Disease by Family History')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %% [markdown]
# # 11. What are the common characteristics of individuals with high stress levels?

# %%
ndf=df[df['Stress Level'] >= 7]

# %%
sns.scatterplot(x='Stress Level',y='Heart Rate',data=ndf)
# plt.legend(['data1','data2'])
plt.show()

# %%
sns.scatterplot(x='Stress Level',y='Blood Pressure',data=ndf)
# Out:
# <Axes: xlabel='Stress Level', ylabel='Blood Pressure'>

# %%
sns.scatterplot(x='Stress Level',y='Cholesterol',data=ndf)
# Out:
# <Axes: xlabel='Stress Level', ylabel='Cholesterol'>

# %% [markdown]
# Scatter plot is not making good understanding so i convert all results into barplot

# %%
ndf=df[df['Stress Level'] >= 7]
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.barplot(x='Stress Level',y='Heart Rate',data=ndf)
plt.title('Relation b/w Stress Level and Heart Disease')
plt.subplot(1,3,2)

sns.barplot(x='Stress Level',y='Blood Pressure',data=ndf)
plt.title('Relation b/w Stress Level and Blood Pressure')

plt.subplot(1,3,3)

sns.barplot(x='Stress Level',y='Cholesterol',data=ndf)
plt.title('Relation b/w Stress Level and Cholesterol')

plt.show()

# %% [markdown]
# # 12. How does obesity relate to other health indicators like diabetes and cholesterol?

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)

sns.scatterplot(data=df,x='Obesity',y='Diabetes')
plt.subplot(1,3,2)
sns.scatterplot(data=df,x='Obesity',y='Cholesterol')
plt.subplot(1,3,3)

sns.scatterplot(data=df,x='Diabetes',y='Cholesterol')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)

sns.barplot(data=df,x='Obesity',y='Diabetes')
plt.title('relation b/w obesity and diabetes')

plt.subplot(1,3,2)
sns.barplot(data=df,x='Obesity',y='Cholesterol')
plt.title('relation b/w obesity and cholestrol')

plt.subplot(1,3,3)

sns.barplot(data=df,x='Diabetes',y='Cholesterol')
plt.title('relation b/w diabetes and cholestrol')

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %% [markdown]
# # 13. Is there a pattern between exercise-induced angina and heart disease?

# %%
sns.barplot(data=df,x='Exercise Induced Angina',y='Heart Disease',width=0.4)
plt.xlabel('Exercise Induced Angina')
plt.ylabel('Heart Disease')
plt.title('Relation between Exercise Induced Angina and Heart Disease')
plt.show()

# %% [markdown]
# # 14. What types of chest pain are most common among individuals with heartdisease?

# %%
sns.barplot(data=df,x='Chest Pain Type',y='Heart Disease')
plt.xlabel('Chest Pain')
plt.ylabel('Heart Disease')
plt.title('Type of Chest Pain causing Heart Diseases')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %% [markdown]
# # 15. What are the main findings from the EDA?

# %% [markdown]
# The main findings form this EDA is to measure/check what are the factors that are causing Heart Disesases
# based on differnet catagories that includes  Gender, Age,  Blood Sugar, Cholestrol, Diabetes, Smoking, Life-Style and so on

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Gender',
#  'Cholesterol',
#  'Blood Pressure',
#  'Heart Rate',
#  'Smoking',
#  'Alcohol Intake',
#  'Exercise Hours',
#  'Family History',
#  'Diabetes',
#  'Obesity',
#  'Stress Level',
#  'Blood Sugar',
#  'Exercise Induced Angina',
#  'Chest Pain Type',
#  'Heart Disease']

# %%
ndf=df[df['Gender'] >= 'Male'] # showing only male data
ndf.shape
ndf.head()
# Out:
#     Age Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 1    48   Male          204             165          62  Current
# 2    53   Male          234              91          67    Never
# 5    77   Male          309             110          73    Never
# 9    63   Male          204             141          68   Former
# 11   37   Male          293             148          98  Current
#
#    Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 1              No               5             No       No      No
# 2           Heavy               3            Yes       No     Yes
# 5              No               0             No      Yes     Yes
# 9           Heavy               8             No      Yes      No
# 11       Moderate               6            Yes       No     Yes
#
#     Stress Level  Blood Sugar Exercise Induced Angina  Chest Pain Type  \
# 1              9           70                     Yes   Typical Angina
# ...

# %%
ndf.shape #only males data
# Out:
# (497, 16)

# %%
# co-relation between heart disease and age
sns.violinplot(x='Heart Disease',y='Age',data=df,width=0.4)  #acc to analysis heart disease is starting from the age above 50 
plt.title('Co-relation between Heart Disease and Age')
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create the heatmap
plt.figure(figsize = (10,8))
sns.heatmap(correlation_matrix, cmap = 'coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Calculate the correlation matrix
# ----> 2 correlation_matrix = df.corr()
#       4 # Create the heatmap
#       5 plt.figure(figsize = (10,8))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
sns.violinplot(x='Gender',y='Heart Disease',data=df)
plt.title('Distribution of Heart Disease by Gender')
plt.show()

# %%
df.head()
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1             No               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3             No               4             No      Yes      No
# 4             No               6             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# ...

# %%
sns.countplot(x='Heart Disease',hue='Gender', data=df) # it shows male have a litle bit more heart issues rather then females
# Out:
# <Axes: xlabel='Heart Disease', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           1000 non-null   object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...
